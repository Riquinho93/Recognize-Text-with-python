# %%
# Install library for the project
# !pip install Pillow
# !pip install pytesseract

# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract
from IPython.display import display

# %%
# If you don't have tesseract executable in your PATH
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files (x86)\Tesseract-OCR\tesseract.exe'

# List of available languages
print(pytesseract.get_languages(config=''))
# Out:
# ['eng', 'osd']

# %%
def recognizeText(filename):
    # Convert image to string
    text = pytesseract.image_to_string(Image.open(filename))
    return text

# %%
path_img = 'img.png'
img = Image.open(path_img, 'r')
display(img)

result = recognizeText(path_img)
print("\n ============== RESULT ==============")
print("\n", result)

# Save the result in a txt file
file = open("textResult.txt", "w")
file.write(result)
file.close()
print("Successfully Completed")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=345x146 at 0x28C113E0898>
#  ============== RESULT ==============
#
#  I LOVE YOU
#
#
# Successfully Completed

# %%
path_img2 = 'img2.jpg'
img2 = Image.open(path_img2, 'r')
display(img2)

result2 = recognizeText(path_img2)
print("\n ============== RESULT ==============")
print("\n", result2)

file = open("textResult.txt", "w")
file.write(result2)
file.close()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x28C1171C898>
#  ============== RESULT ==============
#
#  Coffee
#
# “mBeacusei
#
# Alone
# Is Painful

# %%
path_img3 = 'img3.png'
img3 = Image.open(path_img3, 'r')
display(img3)

result3 = recognizeText(path_img3)
print("\n ============== RESULT ==============")
print("\n", result3)

file = open("textResult.txt", "w")
file.write(result3)
file.close()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=183x275 at 0x28C1171CB38>
#  ============== RESULT ==============
#
#  I want someane
# to look at me lhe way
#
# I look at coffee.

# %%
path_img4 = 'img4.jpg'
img4 = Image.open(path_img4, 'r')
display(img4)

result4 = recognizeText(path_img4)
print("\n ============== RESULT ==============")
print("\n", result4)

file = open("textResult.txt", "w")
file.write(result4)
file.close()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x28C1171CC88>
#  ============== RESULT ==============
#
#  WW‘-""'“’l‘F"
#
# !‘|F You BRiNG ME
#
# COFFEE
# WITHOUT HAVING
#
# TO ASK...
# I LOVE YOU.

# %%
path_img5 = 'img5.jpg'
img5 = Image.open(path_img5, 'r')
display(img5)

result5 = recognizeText(path_img5)
print("\n ============== RESULT ==============")
print("\n", result5)

file = open("textResult.txt", "w")
file.write(result5)
file.close()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x715 at 0x28C117355F8>
#  ============== RESULT ==============
#
#  Should salary be in the
# job description?
#
# Yes No
#
# @

# %%
path_img6 = 'img6.jpg'
img6 = Image.open(path_img6, 'r')
display(img6)

result6 = recognizeText(path_img6)
print("\n ============== RESULT ==============")
print("\n", result6)

file = open("textResult.txt", "w")
file.write(result6)
file.close()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x450 at 0x28C117357F0>
#  ============== RESULT ==============
#
#  ‘ ‘ Forbes
#
# To take matters into your own hands, give
# yourself an opportunity to make an
# opportunity for yourself and have people
# excited about your work is empowering.
#
# lssa Roe
# Actress
